# %% [markdown]
# # ストーリー
# - 再学習時にドリフトと、精度異常が起きている
# - ドリフトは分析した以降の日付に起こるようにする（特定のパラメータでだけ生産を行った）
# - 精度異常はコンセプトドリフトが起きていて、塗布液自体に変化があった。
# - 塗布液の情報を加えた再学習モデルと、加えてない再学習モデルを準備して、チャレンジャーで比較する

# %%
! pip install -r requirements.txt
# Out:
# Collecting pulumi<4.0.0,>=3.0.0 (from -r requirements.txt (line 1))
#   Downloading pulumi-3.154.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting pulumi-datarobot<0.9,>=0.8.13 (from -r requirements.txt (line 2))
#   Downloading pulumi_datarobot-0.8.14.tar.gz (109 kB)
# done
# Collecting datarobot==3.4.0 (from -r requirements.txt (line 4))
#   Downloading datarobot-3.4.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting datarobot-predict<1.10,>=1.9.6 (from -r requirements.txt (line 5))
#   Downloading datarobot_predict-1.9.7-py3-none-any.whl.metadata (1.1 kB)
# Collecting datarobotx-idp<0.3,>=0.2.13 (from -r requirements.txt (line 6))
#   Downloading datarobotx_idp-0.2.15-py3-none-any.whl.metadata (10 kB)
# Collecting streamlit<2,>=1.39.0 (from -r requirements.txt (line 8))
#   Downloading streamlit-1.43.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting st-theme<2,>=1.2.3 (from -r requirements.txt (line 9))
#   Downloading st_theme-1.2.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: python-dotenv==1.0.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: pydantic<2.10,>=2.9.2 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (2.9.2)
# Collecting pydantic-settings<2.6,>=2.5.2 (from -r requirements.txt (line 13))
#   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting eval-type-backport<0.3,>=0.2.0 (from -r requirements.txt (line 14))
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting jupyterlab<5,>=4.2.5 (from -r requirements.txt (line 16))
#   Downloading jupyterlab-4.3.5-py3-none-any.whl.metadata (16 kB)
# Collecting papermill<3,>=2.6.0 (from -r requirements.txt (line 17))
#   Downloading papermill-2.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting babel<3,>=2.16 (from -r requirements.txt (line 19))
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pandas<3,>=2.2.3 (from -r requirements.txt (line 20))
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting pytest==8.0.1 (from -r requirements.txt (line 22))
#   Downloading pytest-8.0.1-py3-none-any.whl.metadata (7.7 kB)
# Collecting pytest-cov==4.1.0 (from -r requirements.txt (line 23))
#   Downloading pytest_cov-4.1.0-py3-none-any.whl.metadata (26 kB)
# Collecting pytest-mock==3.12.0 (from -r requirements.txt (line 24))
#   Downloading pytest_mock-3.12.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting mypy==1.11.2 (from -r requirements.txt (line 25))
#   Downloading mypy-1.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (1.9 kB)
# Collecting types-PyYAML==6.0.12.20240917 (from -r requirements.txt (line 26))
#   Downloading types_PyYAML-6.0.12.20240917-py3-none-any.whl.metadata (1.6 kB)
# Collecting ruff==0.6.9 (from -r requirements.txt (line 27))
#   Downloading ruff-0.6.9-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: numpy in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot==3.4.0->-r requirements.txt (line 4)) (1.26.2)
# Requirement already satisfied: pyyaml>=3.11 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot==3.4.0->-r requirements.txt (line 4)) (6.0.2)
# Requirement already satisfied: requests>=2.28.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot==3.4.0->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.6 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot==3.4.0->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: trafaret!=1.1.0,<2.2,>=0.7 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot==3.4.0->-r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.23 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot==3.4.0->-r requirements.txt (line 4)) (1.26.20)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot==3.4.0->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: mypy-extensions<2,>=0.4.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot==3.4.0->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: strenum>=0.4.15 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot==3.4.0->-r requirements.txt (line 4)) (0.4.15)
# Collecting iniconfig (from pytest==8.0.1->-r requirements.txt (line 22))
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging in /etc/system/kernel/.venv/lib/python3.11/site-packages (from pytest==8.0.1->-r requirements.txt (line 22)) (24.2)
# Collecting pluggy<2.0,>=1.3.0 (from pytest==8.0.1->-r requirements.txt (line 22))
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting coverage>=5.2.1 (from coverage[toml]>=5.2.1->pytest-cov==4.1.0->-r requirements.txt (line 23))
#   Downloading coverage-7.6.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: debugpy~=1.8.7 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1)) (1.8.13)
# Requirement already satisfied: dill~=0.3 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1)) (0.3.9)
# Collecting grpcio~=1.66.2 (from pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1))
#   Downloading grpcio-1.66.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Requirement already satisfied: pip<26,>=24.3.1 in ./.venv/lib/python3.11/site-packages (from pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1)) (25.0.1)
# Collecting protobuf~=4.21 (from pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1))
#   Downloading protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pytest-watch>=4.2.0 (from pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1))
#   Downloading pytest-watch-4.2.0.tar.gz (16 kB)
# done
# Collecting semver~=2.13 (from pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1))
#   Downloading semver-2.13.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: six~=1.12 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1)) (1.17.0)
# Collecting parver>=0.2.1 (from pulumi-datarobot<0.9,>=0.8.13->-r requirements.txt (line 2))
#   Downloading parver-0.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: click<9,>=7 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot-predict<1.10,>=1.9.6->-r requirements.txt (line 5)) (8.1.8)
# Requirement already satisfied: py4j<0.11.0,>=0.10.7 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from datarobot-predict<1.10,>=1.9.6->-r requirements.txt (line 5)) (0.10.9.9)
# Requirement already satisfied: altair<6,>=4.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (4.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (4.2.4)
# Requirement already satisfied: pillow<12,>=7.1.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (10.3.0)
# Requirement already satisfied: pyarrow>=7.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (19.0.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (9.0.0)
# Collecting toml<2,>=0.10.1 (from streamlit<2,>=1.39.0->-r requirements.txt (line 8))
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting watchdog<7,>=2.1.5 (from streamlit<2,>=1.39.0->-r requirements.txt (line 8))
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit<2,>=1.39.0->-r requirements.txt (line 8))
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit<2,>=1.39.0->-r requirements.txt (line 8))
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (6.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from pydantic<2.10,>=2.9.2->-r requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from pydantic<2.10,>=2.9.2->-r requirements.txt (line 12)) (2.23.4)
# Collecting async-lru>=1.0.0 (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16))
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (6.28.0)
# Requirement already satisfied: jinja2>=3.0.3 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (3.1.6)
# Requirement already satisfied: jupyter-core in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (5.2.0)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16))
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (2.15.0)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16))
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in ./.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (76.0.0)
# Requirement already satisfied: traitlets in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (5.14.3)
# Requirement already satisfied: nbformat>=5.2.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from papermill<3,>=2.6.0->-r requirements.txt (line 17)) (5.10.4)
# Requirement already satisfied: nbclient>=0.2.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from papermill<3,>=2.6.0->-r requirements.txt (line 17)) (0.10.2)
# Requirement already satisfied: tqdm>=4.32.2 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from papermill<3,>=2.6.0->-r requirements.txt (line 17)) (4.66.4)
# Requirement already satisfied: entrypoints in /etc/system/kernel/.venv/lib/python3.11/site-packages (from papermill<3,>=2.6.0->-r requirements.txt (line 17)) (0.4)
# Collecting ansicolors (from papermill<3,>=2.6.0->-r requirements.txt (line 17))
#   Downloading ansicolors-1.1.8-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from pandas<3,>=2.2.3->-r requirements.txt (line 20)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from pandas<3,>=2.2.3->-r requirements.txt (line 20)) (2025.1)
# Collecting tzdata>=2022.7 (from pandas<3,>=2.2.3->-r requirements.txt (line 20))
#   Downloading tzdata-2025.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: jsonschema>=3.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (4.23.0)
# Requirement already satisfied: toolz in /etc/system/kernel/.venv/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (1.0.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit<2,>=1.39.0->-r requirements.txt (line 8))
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: anyio in /etc/system/kernel/.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (4.8.0)
# Requirement already satisfied: certifi in /etc/system/kernel/.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /etc/system/kernel/.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.0.7)
# Requirement already satisfied: idna in /etc/system/kernel/.venv/lib/python3.11/site-packages (from httpx>=0.25.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: ipython>=7.23.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (9.0.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.6.0)
# Requirement already satisfied: psutil in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (5.9.1)
# Requirement already satisfied: pyzmq>=24 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (26.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jinja2>=3.0.3->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (3.0.2)
# Requirement already satisfied: platformdirs>=2.5 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-core->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (7.16.6)
# Requirement already satisfied: overrides>=5.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.8.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16))
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from nbformat>=5.2.0->papermill<3,>=2.6.0->-r requirements.txt (line 17)) (2.21.1)
# Collecting arpeggio>=1.7 (from parver>=0.2.1->pulumi-datarobot<0.9,>=0.8.13->-r requirements.txt (line 2))
#   Downloading Arpeggio-2.0.2-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: attrs>=19.2 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from parver>=0.2.1->pulumi-datarobot<0.9,>=0.8.13->-r requirements.txt (line 2)) (23.2.0)
# Collecting docopt>=0.4.0 (from pytest-watch>=4.2.0->pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1))
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# done
# Collecting colorama>=0.3.3 (from pytest-watch>=4.2.0->pulumi<4.0.0,>=3.0.0->-r requirements.txt (line 1))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from requests>=2.28.1->datarobot==3.4.0->-r requirements.txt (line 4)) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from anyio->httpx>=0.25.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /etc/system/kernel/.venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (21.2.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit<2,>=1.39.0->-r requirements.txt (line 8))
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: decorator in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (2.19.1)
# Requirement already satisfied: stack_data in /etc/system/kernel/.venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.6.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit<2,>=1.39.0->-r requirements.txt (line 8)) (0.23.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (6.2.0)
# Requirement already satisfied: defusedxml in /etc/system/kernel/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /etc/system/kernel/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (2.0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: ptyprocess in /etc/system/kernel/.venv/lib/python3.11/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: webencodings in /etc/system/kernel/.venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.8.4)
# Requirement already satisfied: fqdn in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: isoduration in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (3.0.0)
# Requirement already satisfied: uri-template in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (24.11.1)
# Requirement already satisfied: wcwidth in /etc/system/kernel/.venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.2.13)
# Requirement already satisfied: cffi>=1.0.1 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (2.6)
# Requirement already satisfied: executing>=1.2.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (3.0.0)
# Requirement already satisfied: pure-eval in /etc/system/kernel/.venv/lib/python3.11/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (0.2.3)
# Requirement already satisfied: pycparser in /etc/system/kernel/.venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /etc/system/kernel/.venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab<5,>=4.2.5->-r requirements.txt (line 16)) (2.9.0.20241206)
# Downloading datarobot-3.4.0-py3-none-any.whl (615 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.0/615.0 kB 222.2 MB/s eta 0:00:00
# Downloading pytest-8.0.1-py3-none-any.whl (333 kB)
# Downloading pytest_cov-4.1.0-py3-none-any.whl (21 kB)
# Downloading pytest_mock-3.12.0-py3-none-any.whl (9.8 kB)
# Downloading mypy-1.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 189.7 MB/s eta 0:00:00
# Downloading types_PyYAML-6.0.12.20240917-py3-none-any.whl (15 kB)
# Downloading ruff-0.6.9-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 385.3 MB/s eta 0:00:00
# Downloading pulumi-3.154.0-py3-none-any.whl (327 kB)
# Downloading datarobot_predict-1.9.7-py3-none-any.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 235.2 MB/s eta 0:00:00
# Downloading datarobotx_idp-0.2.15-py3-none-any.whl (61 kB)
# Downloading streamlit-1.43.1-py2.py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 240.8 MB/s eta 0:00:00
# Downloading st_theme-1.2.3-py3-none-any.whl (75 kB)
# Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading jupyterlab-4.3.5-py3-none-any.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 365.0 MB/s eta 0:00:00
# Downloading papermill-2.6.0-py3-none-any.whl (38 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 221.4 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 383.5 MB/s eta 0:00:00
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading coverage-7.6.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (241 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading grpcio-1.66.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 173.0 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading parver-0.5-py3-none-any.whl (15 kB)
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 372.5 MB/s eta 0:00:00
# Downloading semver-2.13.0-py2.py3-none-any.whl (12 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
# Downloading ansicolors-1.1.8-py2.py3-none-any.whl (13 kB)
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Downloading Arpeggio-2.0.2-py2.py3-none-any.whl (55 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pulumi-datarobot, pytest-watch, docopt
# done
#   Created wheel for pulumi-datarobot: filename=pulumi_datarobot-0.8.14-py3-none-any.whl size=151042 sha256=8470e5938a21638d3d825df4c5bfebc019999afa9490775c8938c9a27303b74a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f974ln4m/wheels/45/83/b9/09f35196e0e0775d11f8602248f65b5db3e238959e20e71bff
# done
#   Created wheel for pytest-watch: filename=pytest_watch-4.2.0-py3-none-any.whl size=13337 sha256=3619b87ad178577c34e0dd3dc5b0f5a809f3b43923490f4325ac3c6f13382ca4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f974ln4m/wheels/c4/ca/14/56e3ad67afc99180c483bc47c226e5798e5bcb28a49cbac7c5
# done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13748 sha256=b50faace8ba852171fe88443c3df858139f73a636dd88abcfe33cf083e71cef4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f974ln4m/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built pulumi-datarobot pytest-watch docopt
# Installing collected packages: docopt, arpeggio, ansicolors, watchdog, tzdata, types-PyYAML, toml, smmap, semver, ruff, protobuf, pluggy, parver, mypy, json5, iniconfig, grpcio, eval-type-backport, coverage, colorama, babel, async-lru, pytest, pydeck, pandas, gitdb, pytest-watch, pytest-mock, pytest-cov, pydantic-settings, gitpython, datarobot, pulumi, datarobotx-idp, datarobot-predict, streamlit, pulumi-datarobot, st-theme, papermill, jupyterlab-server, jupyter-lsp, jupyterlab
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Not uninstalling protobuf at /etc/system/kernel/.venv/lib/python3.11/site-packages, outside environment /home/notebooks/storage/.venv
#     Can't uninstall 'protobuf'. No files were found to uninstall.
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.1
#     Not uninstalling pandas at /etc/system/kernel/.venv/lib/python3.11/site-packages, outside environment /home/notebooks/storage/.venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
#   Attempting uninstall: pydantic-settings
#     Found existing installation: pydantic-settings 2.8.1
#     Not uninstalling pydantic-settings at /etc/system/kernel/.venv/lib/python3.11/site-packages, outside environment /home/notebooks/storage/.venv
#     Can't uninstall 'pydantic-settings'. No files were found to uninstall.
#   Attempting uninstall: datarobot
#     Found existing installation: datarobot 3.6.4
#     Not uninstalling datarobot at /etc/system/kernel/.venv/lib/python3.11/site-packages, outside environment /home/notebooks/storage/.venv
#     Can't uninstall 'datarobot'. No files were found to uninstall.
#   Attempting uninstall: datarobot-predict
#     Found existing installation: datarobot-predict 1.9.4
#     Not uninstalling datarobot-predict at /etc/system/kernel/.venv/lib/python3.11/site-packages, outside environment /home/notebooks/storage/.venv
#     Can't uninstall 'datarobot-predict'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 1.34.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<4.0.0dev,>=3.19.5, but you have protobuf 4.25.6 which is incompatible.
# Successfully installed ansicolors-1.1.8 arpeggio-2.0.2 async-lru-2.0.4 babel-2.17.0 colorama-0.4.6 coverage-7.6.12 datarobot-3.4.0 datarobot-predict-1.9.7 datarobotx-idp-0.2.15 docopt-0.6.2 eval-type-backport-0.2.2 gitdb-4.0.12 gitpython-3.1.44 grpcio-1.66.2 iniconfig-2.0.0 json5-0.10.0 jupyter-lsp-2.2.5 jupyterlab-4.3.5 jupyterlab-server-2.27.3 mypy-1.11.2 pandas-2.2.3 papermill-2.6.0 parver-0.5 pluggy-1.5.0 protobuf-4.25.6 pulumi-3.154.0 pulumi-datarobot-0.8.14 pydantic-settings-2.5.2 pydeck-0.9.1 pytest-8.0.1 pytest-cov-4.1.0 pytest-mock-3.12.0 pytest-watch-4.2.0 ruff-0.6.9 semver-2.13.0 smmap-5.0.2 st-theme-1.2.3 streamlit-1.43.1 toml-0.10.2 types-PyYAML-6.0.12.20240917 tzdata-2025.1 watchdog-6.0.0

# %%
from datetime import date, timedelta
import random

import pandas as pd
import numpy as np

import datarobot as dr


df = pd.read_csv("../assets/コーティング製品ブリードアウトmain_train.csv")
# 塗布長を短いやつだけにする
sample = df.sample(n=200, random_state=42)


def generate_binary_list(n, p):
  """
  0と1の整数のリストを生成する。

  Args:
    n: リストの長さ。
    p: 1が出現する確率。

  Returns:
    0と1の整数のリスト。

  # パラメータ設定
  n = 200  # リストの長さ
  ratio_0 = 3  # 0の比率
  ratio_1 = 1  # 1の比率
  p = ratio_1 / (ratio_0 + ratio_1)  # 1が出現する確率

  # リスト生成
  binary_list = generate_binary_list(n, p)
  """
  return np.random.binomial(1, p, n).tolist()

# データドリフト用のデータを作る

# パラメータ設定
n = 200  # リストの長さ
ratio_0 = 3  # 0の比率
ratio_1 = 1  # 1の比率
p = ratio_1 / (ratio_0 + ratio_1)  # 1が出現する確率

# リスト生成
binary_list = generate_binary_list(n, p)

sample["塗布長"] = binary_list
sample["塗布長"] = sample["塗布長"].map({0:"30m", 1:"100m"})



# 予測時に日付の情報を乗せたいので日付を作る
def get_last_week_dates():
  """今日から1週間前までの毎日の日付を"%Y-%m-%d"形式のリストで返す。"""
  today = date.today()
  dates = []
  for i in range(7):
    current_date = today - timedelta(days=i)
    dates.append(current_date.strftime("%Y-%m-%d"))
  return dates

# 実行例
last_week_dates = get_last_week_dates()
print(last_week_dates)

# データドリフトが起きてないデータをサンプルして作る。
sample_list = []
for i in range(6):
    _df =  df.sample(n=200, random_state=i)
    _df["date_col"] = last_week_dates.pop(0)
    sample_list.append(_df)
sample["date_col"] = last_week_dates.pop(0)
sample_list.append(sample)

# ランダムに割り付けたdataframeを一つにする
sample = pd.concat(sample_list)

# 精度の監視のためにロット番号を更新する
lot_num = []
init_num = 10000
for i in range(sample.shape[0]):
    lot_num.append(f"SC{str(init_num).zfill(7)}")
    init_num += 1
sample["ロット番号"] = lot_num

# 保存する
sample.to_csv("data_drift.csv", index=False)

# 翌週のデータを作る
def get_next_week_dates():
  """今日から1週間前までの毎日の日付を"%Y-%m-%d"形式のリストで返す。"""
  today = date.today()
  dates = []
  for i in range(1, 8):
    current_date = today + timedelta(days=i)
    dates.append(current_date.strftime("%Y-%m-%d"))
  return dates

# 実行例
next_week_dates = get_next_week_dates()
print(next_week_dates)

# サンプリングして日付をつける
sample_list = []
for i in range(8, 15):
    sample = df.sample(n=200, random_state=i)
    sample["date_col"] = next_week_dates.pop(0)
    sample_list.append(sample)
sample_df_next_week = pd.concat(sample_list)

# ロット番号をつける
lot_num = []
init_num = 11400
for i in range(sample_df_next_week.shape[0]):
    lot_num.append(f"SC{str(init_num).zfill(7)}")
    init_num += 1
sample_df_next_week["ロット番号"] = lot_num
# 保存する
sample_df_next_week.to_csv("next_week.csv", index=False)


# 精度のためにデータを確率で入れ替える
def replace_false_with_true_numpy(binary_list, probability):
  """
  NumPyを使ってFalseをTrueに置き換える関数。

  Args:
    binary_list: TrueとFalseのバイナリリスト。
    probability: FalseをTrueに置き換える確率 (0から1の範囲)。

  Returns:
    FalseがTrueに置き換えられた新しいバイナリリスト。
  """
  arr = np.array(binary_list)
  random_values = np.random.rand(len(arr))
  arr = np.logical_or(arr, random_values < probability)
  return arr.tolist()

sample_last_week = pd.read_csv("data_drift.csv")
bleedout = []

# 少しづつ異常が増えていくようにする
for date in sample_last_week["date_col"].unique():
    _tmp = sample_last_week[sample_last_week["date_col"] == date]
    binary_tmp = _tmp["ブリードアウト"].tolist()
    if date == '2025-03-14':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.02)
    if date == '2025-03-15':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.04)
    if date == '2025-03-16':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.06)
    bleedout.extend(binary_tmp)

sample_last_week["ブリードアウト"] = bleedout

# 保存する
sample_last_week.to_csv("data_drift_modify.csv", index=False)
sample_last_week[["ロット番号", "ブリードアウト"]].to_csv("正解データ1.csv",index=False)

# 先の日付についても同様に行う
bleedout = []

for date in sample_df_next_week["date_col"].unique():
    _tmp = sample_df_next_week[sample_df_next_week["date_col"] == date]
    binary_tmp = _tmp["ブリードアウト"].tolist()
    if date == '2025-03-17':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.08)
    if date == '2025-03-18':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.1)
    if date == '2025-03-19':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.12)
    if date == '2025-03-20':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.14)
    if date == '2025-03-21':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.16)
    if date == '2025-03-22':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.18)
    if date == '2025-03-23':
        binary_tmp = replace_false_with_true_numpy(binary_tmp, 0.2)
    bleedout.extend(binary_tmp)


sample_df_next_week["ブリードアウト"] = bleedout
sample_df_next_week.to_csv("next_week_modify.csv", index=False)
sample_df_next_week[["ロット番号", "ブリードアウト"]].to_csv("正解データ2.csv",index=False)
# Out:
# ['2025-03-19', '2025-03-18', '2025-03-17', '2025-03-16', '2025-03-15', '2025-03-14', '2025-03-13']
# ['2025-03-20', '2025-03-21', '2025-03-22', '2025-03-23', '2025-03-24', '2025-03-25', '2025-03-26']

# %% [markdown]
# # 新しい行の追加と予測用にデータ保存

# %%
rate = 3
import pandas as pd

# 過去データ読み込み
original_data = pd.read_csv('../data_drift_original.csv')
drift_data = pd.read_csv("../data_drift_modify.csv")
new_data = drift_data.copy()
new_data["塗布材料"] = "A"

# 塗布材料作成
new_data.loc[original_data["ブリードアウト"] != drift_data["ブリードアウト"], "塗布材料"] = "B"

# 新しい塗布材料のインデックス指定
replace_index = []
for i in new_data["date_col"].unique():
    if i == '2025-03-14':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.02/rate), random_state=42).index)
        #replace_index.append()
    if i == '2025-03-15':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.04/rate), random_state=42).index)
    if i == '2025-03-16':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.06/rate), random_state=42).index)

# 置換
new_data.loc[replace_index, "塗布材料"] = "B"

# 日付順にソート
new_data["date_col"] = pd.to_datetime(new_data["date_col"])
new_data = new_data.sort_values(by='date_col', ascending=True)
lot_num = []
init_num = 10000
for i in range(drift_data.shape[0]):
    lot_num.append(f"SC{str(init_num).zfill(7)}")
    init_num += 1
new_data['ロット番号'] = lot_num
new_data = new_data.reset_index(drop=True)

# 書き出し
new_data.to_csv('../assets/data_01.csv', index=False)

# %%
original_data = pd.read_csv('../next_week.csv')
drift_data = pd.read_csv("../next_week_modify.csv")
new_data = drift_data.copy()
new_data["塗布材料"] = "A"

# 塗布材料の行作成

new_data.loc[original_data["ブリードアウト"] != drift_data["ブリードアウト"], "塗布材料"] = "B"

# 新しい塗布材料のインデックス指定

replace_index = []
for i in new_data["date_col"].unique():
    if i == '2025-03-17':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.08/rate), random_state=42).index)
        #replace_index.append()
    if i == '2025-03-18':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.1/rate), random_state=42).index)
    if i == '2025-03-19':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.12/rate), random_state=42).index)
        #replace_index.append()
    if i == '2025-03-20':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.14/rate), random_state=42).index)
    if i == '2025-03-21':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.16/rate), random_state=42).index)
        #replace_index.append()
    if i == '2025-03-22':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.18/rate), random_state=42).index)

    if i == '2025-03-23':
        _tmp = new_data[(new_data["date_col"]==i) & (new_data["ブリードアウト"]==False)]
        replace_index.extend(_tmp.sample(n=int(_tmp.shape[0]*0.2/rate), random_state=42).index)


# 置換
new_data.loc[replace_index, "塗布材料"] = "B"

new_data.to_csv('../assets/data_02.csv', index=False)

# %%
data_01 = pd.read_csv("../assets/data_01.csv")
data_02 = pd.read_csv("../assets/data_02.csv")
df = pd.read_csv("../assets/コーティング製品ブリードアウトmain_train.csv")

# 02（将来のデータ）と塗布液変更データを含まずに再学習用のデータとした
pd.concat([df, data_01.drop(columns=['date_col', '塗布材料'])]).to_csv('../assets/再学習用データ01.csv', index=False)

# 02（将来のデータ）なしで塗布液変更データを含んで再学習用のデータとした
df['塗布材料'] = "A"
pd.concat([df, data_01.drop(columns=['date_col'])]).to_csv('../assets/再学習用データ02.csv', index=False)

# 02（将来のデータ）を含んで再学習用のデータとした。
pd.concat([df, data_01.drop(columns=['date_col']), data_02.drop(columns=['date_col'])]).to_csv('../assets/再学習用データ03.csv', index=False)

# todo
# 将来データ移行の予測データも作る。

# 予測用データと実績値データを作る。
prediction_data = pd.concat([data_01, data_02])
prediction_data.drop(columns=['ブリードアウト', '塗布材料']).to_csv("../assets/prediction_data.csv", index=False)
prediction_data[['ロット番号', 'ブリードアウト']].to_csv("../assets/prediction_data_actual.csv", index=False)
